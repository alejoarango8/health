# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import csv
import unidecode
import os
import numpy as np
import zlib
import dateutil
import datetime
from ipywidgets import widgets, interactive_output
from IPython.display import display
import random
import itertools

# %% [markdown]
# # Lectura de Tablas

# %%
# Lista con los nombres de los archivos csv de la tablas
names = [os.path.splitext(i)[0] for i in os.listdir("data") if os.path.splitext(i)[0].startswith("df")]

# %%
# Lectura de las tablas
for i in names:
  # Lectura de cronicos
  if i.endswith("cronicos"):
    # Crear DataFrame
    df = pd.read_csv(f'data/{i}.csv', delimiter=";", encoding="latin-1", low_memory=False)

    # Cambiar caracteres especiales de las columnas
    with open(f'data/{i}.csv', "r", encoding="utf-8") as f:
      # Leer primera fila (nombre de columnas)
      text = csv.reader(f)
      # Crear variable
      columns = next(text)

    # Remover caracteres especiales
    columns = unidecode.unidecode(columns[0]).split(";")
    # Cambiar nombre de columnas en el DataFrame
    df.columns = columns
    # Reemplazar valores sin informacion por valores nulos
    df.replace(["", "([sS]in\s)", "ND"], [np.nan]*3, regex=True, inplace=True)
    # Crear variables locales de los diferentes DataFrames
    locals().update({i:df})

  # Lectura usuarios y egresos
  else:
    # Crear DataFrame
    df = pd.read_csv(f'data/{i}.csv', delimiter=",", encoding="latin-1", low_memory=False)

    # Cambiar caracteres especiales de las columnas
    with open(f'data/{i}.csv', "r", encoding="utf-8") as f:
      # Leer primera fila (nombre de columnas)
      text = csv.reader(f)
      # Crear variable
      columns = next(text)
      # rows = np.array([unidecode.unidecode(";".join(i)).split(";") for i in text])

    # Remover caracteres especiales
    columns = unidecode.unidecode(";".join(columns)).split(";")
    # dic = {j:rows[:,i] for i,j in enumerate(columns)}
    # df = pd.DataFrame(dic)
    # Cambiar nombre de columnas en el DataFrame
    df.columns = columns
    # Reemplazar valores sin informacion por valores nulos
    df.replace(["", "([sS]in\s)", "ND"], [np.nan]*3, regex=True, inplace=True)
    # Crear variables locales de los diferentes DataFrames
    locals().update({i:df})

# %% [markdown]
# # Valores nulos antes de exploracion y procesamiento

# %%
# Crear figura
fig, axes = plt.subplots(1, 3, figsize=(7*((1+np.sqrt(5))/2), 7))

# Iterar por cada base de datos
for i, j, k in zip(range(3), [df_cronicos, df_usuarios, df_egresos], ["Cronicos", "Usuarios", "Egresos"]):

  df_na = j.isna().apply(pd.Series.value_counts, normalize=True).T.fillna(0)

  df_na.sort_values(by=True, ascending=False).plot(kind="barh", stacked=True, legend=False, ax=axes[i], title=k)
  if i == 1:
    axes[i].set_yticklabels(df_na.sort_values(by=True, ascending=False).index ,fontsize=7)
  else:
    axes[i].set_yticks([])

fig.suptitle("Porcentaje de valores nulos\n por columna en los DataFrames")
fig.legend(axes[0].patch, labels=["Con informacion", "Sin informacion"])
plt.tight_layout()
plt.show()
# Out:
# C:\Users\USUARIO\AppData\Local\Temp\ipykernel_11712\2022302661.py:16: UserWarning: You have mixed positional and keyword arguments, some input may be discarded.
#   fig.legend(axes[0].patch, labels=["Con informacion", "Sin informacion"])

# %%
(df_egresos.isna().sum() > df_egresos.shape[0]/2).value_counts(normalize=True).sort_values(ascending=False)

# df_egresos.shape[0]
# Out:
# False    0.681818
# True     0.318182
# Name: proportion, dtype: float64

# %%
# Crear figura
fig, axes = plt.subplots(1, 3, figsize=(6*((1+np.sqrt(5))/2), 6))

# Iterar por cada base de datos
for i, j, k in zip(range(3), [df_cronicos, df_usuarios, df_egresos], ["Cronicos", "Usuarios", "Egresos"]):

  df_na = (j.isna().sum() > int(j.shape[0]/2)).value_counts()
  axes[i].pie(df_na.values, autopct="%1.0f%%", labels=[df_na.sort_values(ascending=False).index[0], df_na.sort_values(ascending=False).index[1]])
  axes[i].set_title(k)
  axes[i].legend()


fig.suptitle("Porcentaje de columnas con mas de la mitad de valores nulos\npor DataFrame")
# fig.legend(axes[0].patch, labels=["Con informacion", "Sin informacion"])
fig.tight_layout()
fig.show()
# Out:
# C:\Users\USUARIO\AppData\Local\Temp\ipykernel_11712\1162272179.py:16: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %%
wid_1 = widgets.Dropdown(options=df_cronicos.loc[:,"NRODOC"].unique().tolist())

def groupby(user):

  df = df_cronicos.groupby("NRODOC").get_group(user)
  display(df)

output = interactive_output(groupby, {"user":wid_1})

display(wid_1, output)
# Out:
# Dropdown(options=(311144, 308418, 308573, 307549, 307044, 309419, 308437, 308637, 308561, 308563, 310132, 3105…
# Output()

# %% [markdown]
# # Usuarios

# %%
df_usuarios_t = df_usuarios.copy()

# Columnas con el mismo valor para todos los usuarios
cols = ["FECHA NACIMIENTO", "BARRIO", "MUNICIPIO", "DEPARTAMENTO", "FECHA INICIO AL PGP", "FECHA PRIMERA CLASE FUNCIONAL", "PRIMERA CLASE FUNCIONAL"]

# Filtro de usuarios mayores de 60 años y con valores NA
mask = (df_usuarios_t["EDAD"] >= 60) | (df_usuarios_t["EDAD"].isna())

# Filtrar base de datos
df_usuarios_t = df_usuarios_t[mask]

# Convertir fechas a formato date time
df_usuarios_t["FECHA NACIMIENTO"] = pd.to_datetime(df_usuarios_t["FECHA NACIMIENTO"], format="mixed")

# Diccionario con numeros de meses
spanish_months = {"ENERO": 1, "FEBRERO": 2, "MARZO": 3, "ABRIL": 4,
                  "MAYO": 5, "JUNIO": 6, "JULIO": 7, "AGOSTO": 8,
                  "SEPTIEMBRE": 9, "OCTUBRE": 10, "NOVIEMBRE": 11, "DICIEMBRE": 12}

# Cambio de nombre a numero de mes
df_usuarios_t["MES"] = df_usuarios_t["MES"].replace(spanish_months)

# Creacion de columna datetime con la fecha de diligenciamiento del formulario
df_usuarios_t["DATE"] = pd.to_datetime((df_usuarios_t["YEAR"].astype(str) + "/" + df_usuarios_t["MES"].astype(str)), format="%Y/%m")

# Llenar valores nulos de las columnas repetidas para cada paciente
for i in df_usuarios_t["NRODOC"].unique():

    df_usuarios_t.loc[df_usuarios_t.groupby("NRODOC").get_group(i).index, cols] = df_usuarios_t.groupby("NRODOC").get_group(i)[cols].bfill().ffill()

# Indexes con valores nulos para la fecha de nacimiento
fnna_index = df_usuarios_t[df_usuarios_t["FECHA NACIMIENTO"].isna()].index

# Reemplazar los valores de la fecha de nacimiento de los index previos
for id in df_usuarios.loc[fnna_index, "NRODOC"].unique().tolist():

  df = df_usuarios_t.copy().groupby("NRODOC").get_group(id)

  edad = df["EDAD"].min()
  fecha = df["DATE"].min()
  try:

    birth = fecha - datetime.timedelta(days=edad*365.25)
    df_usuarios_t.loc[df_usuarios_t["NRODOC"] == id, "FECHA NACIMIENTO"] = df.groupby("NRODOC").get_group(id)["FECHA NACIMIENTO"].fillna(birth)

  except ValueError:
    pass

# Eliminar filas con Edad y Fecha de nacimiento nulas (no se tiene informacion del paciente)
df_usuarios_t.dropna(subset=["EDAD", "FECHA NACIMIENTO"], how="all", inplace=True)

# Modificar columna edad con resta de fecha de nacimiento y fecha de diligenciamiento del formulario
df_usuarios_t["EDAD"] = ((df_usuarios_t["DATE"] - df_usuarios_t["FECHA NACIMIENTO"])/datetime.timedelta(days=365.25)).round(0).astype(int)

# Filtro con usuarios mayores a 60 años luego de tratar valores
mask = (df_usuarios_t["EDAD"] >= 60)

# Filtrar usuarios mayores a 60 años
df_usuarios_t = df_usuarios_t[mask]

to_drop = ["MES", "YEAR", "DEPARTAMENTO", "QUINQUENIO", "CICLO_VITAL", "FECHA INICIO AL PGP"]

df_usuarios_t.drop(to_drop, axis=1, inplace=True)

df_usuarios_t.drop(df_usuarios_t[df_usuarios_t["PRIMERA CLASE FUNCIONAL"].str.contains("4").fillna(False)].index, inplace=True)

df_usuarios_t.loc[~df_usuarios_t["SEXO"].isin(["F", "M"]), "SEXO"] = [random.choice(["F", "M"]) for i in range(len(df_usuarios_t[~df_usuarios_t["SEXO"].isin(["F", "M"])]))]

# Calcula el porcentaje de valores nulos en cada variable
porcentaje_nulos = (df_usuarios_t.isnull().sum() / len(df_usuarios_t)) * 100

# Filtra las variables que tienen más del 10% de valores nulos
variables_con_nulos = porcentaje_nulos[porcentaje_nulos > 10].index

# Elimina las variables con más del 10% de valores nulos del DataFrame
df_usuarios_t.drop(variables_con_nulos, axis=1, inplace=True)

# %%
df_usuarios_t = pd.read_csv("data/df_usuarios_t.csv", low_memory=False, parse_dates=["DATE"])

# %%
to_drop = ["MES", "YEAR", "DEPARTAMENTO", "QUINQUENIO", "CICLO_VITAL", "FECHA INICIO AL PGP"]

df_usuarios_t.drop(to_drop, axis=1, inplace=True)

df_usuarios_t.drop(df_usuarios_t[df_usuarios_t["PRIMERA CLASE FUNCIONAL"].str.contains("4").fillna(False)].index, inplace=True)

# Calcula el porcentaje de valores nulos en cada variable
porcentaje_nulos = (df_usuarios_t.isnull().sum() / len(df_usuarios_t)) * 100

# Filtra las variables que tienen más del 10% de valores nulos
variables_con_nulos = porcentaje_nulos[porcentaje_nulos > 10].index

# Elimina las variables con más del 10% de valores nulos del DataFrame
df_usuarios_t.drop(variables_con_nulos, axis=1, inplace=True)

df_usuarios_t.loc[~df_usuarios_t["SEXO"].isin(["F", "M"]), "SEXO"] = [random.choice(["F", "M"]) for i in range(len(df_usuarios_t[~df_usuarios_t["SEXO"].isin(["F", "M"])]))]

# %%
wid_1 = widgets.Dropdown(options=df_usuarios["NRODOC"].unique().tolist())

def groupby(user):

  df = df_usuarios_t.groupby("NRODOC").get_group(user)
  display(df)

output = interactive_output(groupby, {"user":wid_1})

display(wid_1, output)

# %%
# Usuarios mayores de 60
ids = df_usuarios_t["NRODOC"].unique()

# %% [markdown]
# # Cronicos

# %%
df_cronicos = df_cronicos[df_cronicos["NRODOC"].isin(ids)]

# %%
# Calcula el porcentaje de valores nulos en cada variable
porcentaje_nulos = (df_cronicos.isnull().sum() / len(df_cronicos)) * 100

# Filtra las variables que tienen más del 10% de valores nulos
variables_con_nulos = porcentaje_nulos[porcentaje_nulos > 10].index

# Elimina las variables con más del 10% de valores nulos del DataFrame
df_cronicos.drop(variables_con_nulos, axis=1, inplace=True)

# Modificar Fecha de diligenciamiento agregando la hora
df_cronicos["Fecha diligenciamiento"] = pd.to_datetime((df_cronicos["Fecha diligenciamiento"].astype(str) + " " + df_cronicos["Hora"].astype(str)), format="mixed")

# Eliminar columnas con informacion repetida
df_cronicos.drop(["YEAR", "MES", "Hora"], axis=1, inplace=True)

# %%
df_cronicos.isna().sum()
# Out:
# Fecha diligenciamiento                          0
# Atencion                                        0
# Ingreso                                         0
# Tipo                                            0
# NRODOC                                          0
# Peso                                            0
# Talla                                           0
# IMC                                             0
# Clasificacion IMC                               0
# Saturacion de Oxigeno (%)                      99
# Perimetro Muslo                                 0
# Perimetro Cintura                               0
# Pliegue Triceps                                 0
# Pliegue Abdomen                                 0
# Pliegue Muslo                                   0
# Sumatoria Pliegues                              0
# Presion Arterial Sistolica                      0
# Presion Arterial Diastolica                     0
# Frecuencia Cardiaca en reposo                   0
# Auto-calificacion Nivel de Ejercicio            0
# Constantes                                      0
# METS -Indice Metabolico                         0
# VO2 - Maxima Cantidad de Oxigeno                0
# Indice de Fragilidad Groningen                 44
# Calificacion (Indice de Fragilidad)             0
# Tiempo en Segundos (Apoyo Monopodal)            0
# Calificacion (Apoyo Monopodal)                  0
# Tiempo en Segundos (Recorrer 5 metros)          0
# Velocidad (m/s)                                 0
# Calificacion Velocidad                          0
# Diabetes Mellitus                             663
# Glicemia                                      663
# Hemoglobina Glicada                           663
# Control Diabetes                              663
# Tiene HTA                                     663
# Tiene EPOC                                    663
# Enfermedad Coronaria (En el ultimo ano)       663
# Insuficiencia Cardiaca                        663
# Valvulopatia                                  663
# Arritmia o paciente con dispositivo           663
# Sufre de alguna enfermedad cardiovascular     663
# Tabaquismo                                    830
# Lipoproteina                                  830
# HDL                                           830
# Colesterol total                              830
# Trigliceridos                                 830
# Creatinina 1 consulta                         830
# Tasa de Filtracion Glomerular TFG             830
# Estadio de la Enfermedad Renal               2580
# Microalbuminuria                              830
# Hormona Estimulante de la Tiroides (TSH)      830
# Clase Funcional                               830
# Creatinina 2 consulta                         830
# Tasa de Filtracion Glomerular TFG2            830
# Meses de diferencia entre TFG                 830
# Cambio de TFG                                 830
# Ulcera de pie diabetico                      1986
# Remision                                      830
# dtype: int64

# %%
# Columnas con valores nulos luego de la eliminacion por el umbral
na_cols = df_cronicos.isna().sum()[df_cronicos.isna().sum() > 0].index.values.tolist() + ["Tipo", "Ingreso"]

df_cronicos.drop(na_cols, axis=1, inplace=True)

# %%
wid_1 = widgets.Dropdown(options=na_cols)

def plot_na(col):

  df = pd.concat([df_cronicos["Fecha diligenciamiento"], df_cronicos[col].isna()], axis=1).set_index("Fecha diligenciamiento").resample("M").sum()
  df.plot(kind="line")
  plt.show()

output = interactive_output(plot_na, {"col":wid_1})

display(wid_1, output)
# Out:
# Dropdown(options=('Saturacion de Oxigeno (%)', 'Indice de Fragilidad Groningen', 'Test Findrisc', 'Diabetes Me…
# Output()

# %%
# Obtener solo las variables numéricas
variables_numericas = df_cronicos.select_dtypes(include=['number']).columns.tolist()

# Función para visualizar boxplots de una variable numérica
def visualizar_boxplot(nombre_variable):
    plt.figure(figsize=(8, 6))
    sns.boxplot(data=df, y=nombre_variable)
    plt.title("Boxplot de la variable: {}".format(nombre_variable))
    plt.xlabel("Valor")
    plt.ylabel("Variable")
    plt.show()

# Crear lista desplegable para seleccionar variable
opciones_variables = [(variable, variable) for variable in variables_numericas]
lista_desplegable = widgets.Dropdown(options=opciones_variables, description='Variable:')

# Llamar a la función visualizar_boxplot cuando se seleccione una variable
widgets.interactive(visualizar_boxplot, nombre_variable=lista_desplegable)
# Out:
# interactive(children=(Dropdown(description='Variable:', options=(('YEAR', 'YEAR'), ('AtenciA3n', 'AtenciA3n'),…

# %%
# Función para visualizar la distribución de una variable
def visualizar_variable(nombre_variable):
    plt.figure(figsize=(8, 6))
    # Seleccionar el tipo de gráfico según el tipo de variable
    if df_cronicos[nombre_variable].dtype == 'object':
        df_cronicos[nombre_variable].value_counts().plot(kind='pie')
    else:
        df_cronicos[nombre_variable].plot(kind='hist', bins=20)
    plt.title("Distribución de la variable: {}".format(nombre_variable))
    plt.xlabel("Valor")
    plt.ylabel("Frecuencia")
    plt.show()

# Lista de variables en el DataFrame
variables = df_cronicos.columns.tolist()

# Crear lista desplegable para seleccionar variable
opciones_variables = [(variable, variable) for variable in variables]
lista_desplegable = widgets.Dropdown(options=opciones_variables, description='Variable:')

# Llamar a la función visualizar_variable cuando se seleccione una variable
widgets.interactive(visualizar_variable, nombre_variable=lista_desplegable)
# Out:
# interactive(children=(Dropdown(description='Variable:', options=(('YEAR', 'YEAR'), ('MES', 'MES'), ('Fecha dil…

# %%
# Calcular el número de ocurrencias de cada calse funcional por año
ocurrencias_por_año = df_cronicos.groupby(['YEAR', 'Clase Funcional'])['Clase Funcional'].count().unstack()

# Graficar el número de ocurrencias de cada clase funcional por año
ocurrencias_por_año.plot(kind='bar', stacked=True, figsize=(10, 6))
plt.xlabel('Año')
plt.ylabel('Número de ocurrencias')
plt.title('Número de ocurrencias por subcategoría y año')
plt.legend(title='Subcategoría', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.grid(axis='y')
plt.show()

# %% [markdown]
# # Egresos

# %%
df_egresos
# Out:
#       YEAR        MES  NRO ATENCION  NRO INGRESO  SERVICIO HABILITADO COD  \
# 0     2017       MAYO       3433964      1899917                     -1.0
# 1     2017  DICIEMBRE       3720631      2018136                     -1.0
# 2     2018    FEBRERO       3912821      2159592                    501.0
# 3     2018       MAYO       4023613      2254075                    501.0
# 4     2018      JULIO       4080166      2292863                    101.0
# ...    ...        ...           ...          ...                      ...
# 6371  2021      MARZO       5534142      3741912                    101.0
# 6372  2018    FEBRERO       3887839      2138151                    101.0
# 6373  2018      MARZO       3961138      2204868                    101.0
# 6374  2021  NOVIEMBRE       5883105      4110965                    101.0
# 6375  2021    OCTUBRE       5857866      4084538                    107.0
#
#              SERVICIO HABILITADO TIPO IDENTIFICACION  NRODOC  \
# 0                            NaN                  CC  308185
# 1                            NaN                  CC  308185
# 2          Urgencias >= 24 horas                  CC  308185
# 3          Urgencias >= 24 horas                  CC  308185
# 4                General adultos                  CC  308185
# ...                          ...                 ...     ...
# 6371             General adultos                  CC  312056
# 6372             General adultos                  CC  308757
# 6373             General adultos                  CC  308759
# 6374             General adultos                  CC  313987
# 6375  Cuidado Intermedio Adultos                  CC  313921
#
#              FECHA NACIMIENTO REGIMEN AFILIACION        EPS VALIDADA  \
# 0     1937-07-18 00:00:00.000                NaN                 NaN
# 1     1937-07-18 00:00:00.000                NaN                 NaN
# 2     1937-07-18 00:00:00.000       Contributivo  NUEVA EPS S.A. PGP
# 3     1937-07-18 00:00:00.000       Contributivo  NUEVA EPS S.A. PGP
# 4     1937-07-18 00:00:00.000       Contributivo  NUEVA EPS S.A. PGP
# ...                       ...                ...                 ...
# 6371  1949-05-09 00:00:00.000       Contributivo  NUEVA EPS S.A. PGP
# 6372  1951-06-08 00:00:00.000       Contributivo  NUEVA EPS S.A. PGP
# 6373  1935-09-29 00:00:00.000       Contributivo  NUEVA EPS S.A. PGP
# 6374  1953-09-30 00:00:00.000       Contributivo  NUEVA EPS S.A. PGP
# 6375  1960-06-09 00:00:00.000       Contributivo  NUEVA EPS S.A. PGP
#
#      MODALIDAD CONTRATO FUENTE FINANCIACION1 FUENTE FINANCIACION2  \
# 0                   NaN                  NaN                  NaN
# 1                   NaN                  NaN                  NaN
# 2                   PGP            NUEVA EPS            NUEVA EPS
# 3                   PGP            NUEVA EPS            NUEVA EPS
# 4                   PGP            NUEVA EPS            NUEVA EPS
# ...                 ...                  ...                  ...
# 6371                PGP            NUEVA EPS            NUEVA EPS
# 6372                PGP            NUEVA EPS            NUEVA EPS
# 6373                PGP            NUEVA EPS            NUEVA EPS
# 6374                PGP            NUEVA EPS            NUEVA EPS
# 6375                PGP            NUEVA EPS            NUEVA EPS
#
#                   SERVICIO ADMITE BLOQUE ANTERIOR PISO ANTERIOR  \
# 0     Urgencias Generales SÃ³tano             NaN           NaN
# 1     Urgencias Generales SÃ³tano             NaN           NaN
# 2     Urgencias Generales SÃ³tano             NaN           NaN
# 3     Urgencias Generales SÃ³tano             NaN           NaN
# 4     Urgencias Generales SÃ³tano        Bloque 3     Urgencias
# ...                           ...             ...           ...
# 6371  Urgencias Generales SÃ³tano        Bloque 3     Urgencias
# 6372  Urgencias Generales SÃ³tano        Bloque 3     Urgencias
# 6373  Urgencias Generales SÃ³tano        Bloque 1       Piso 10
# 6374  Urgencias Generales SÃ³tano        Bloque 3     Urgencias
# 6375  Urgencias Generales SÃ³tano        Bloque 3     Urgencias
#
#                SERVICIO ANTERIOR NRO CAMA ANTERIOR VIA INGRESO    BLOQUE  \
# 0                            NaN               NaN         NaN       NaN
# 1                            NaN               NaN         NaN       NaN
# 2                            NaN               NaN   Urgencias  Bloque 3
# 3                            NaN               NaN   Urgencias  Bloque 3
# 4                          ERA 1            ERA106   Urgencias  Bloque 1
# ...                          ...               ...         ...       ...
# 6371  Camillas Sala 6  Urgencias               608   Urgencias  Bloque 1
# 6372                  ExpansiÃ³n            EXP415   Urgencias  Bloque 1
# 6373    Piso_10 Medicina Interna             1011B   Urgencias  Bloque 1
# 6374                Fast track 2            FST203   Urgencias  Bloque 1
# 6375       Urgencias Expansion 1            EXP108   Urgencias  Bloque 3
#
#            UNIDAD ESTRATEGICA       PISO NRO CAMA  \
# 0     Hospitalizacion Adultos        NaN      NaN
# 1     Hospitalizacion Adultos        NaN      NaN
# 2                   Urgencias  Urgencias   FST101
# 3                   Urgencias  Urgencias   ERA109
# 4     Hospitalizacion Adultos     Piso 7    711BS
# ...                       ...        ...      ...
# 6371  Hospitalizacion Adultos     Piso 7    704AS
# 6372  Hospitalizacion Adultos     Piso 7    732AN
# 6373  Hospitalizacion Adultos    Piso 10    1004A
# 6374  Hospitalizacion Adultos     Piso 4    427BN
# 6375      CUIDADOS ESPECIALES     Piso 6   UCE609
#
#                     SERVICIO EGRESO                    TIPO EGRESO  \
# 0                               NaN                            NaN
# 1                               NaN                            NaN
# 2                      Fast track 1                   Alta MÃ©dica
# 3                             ERA 1                   Alta MÃ©dica
# 4       Piso 7 Medicina Interna Sur                   Alta MÃ©dica
# ...                             ...                            ...
# 6371    Piso 7 Medicina Interna Sur                   Alta MÃ©dica
# 6372  Piso 7 Medicina Interna Norte                   Alta MÃ©dica
# 6373       Piso_10 Medicina Interna                   Alta MÃ©dica
# 6374  Piso 4 Medicina Interna Norte                   Alta MÃ©dica
# 6375                     Piso 6 UCE  RemisiÃ³n a otra instituciÃ³n
#
#         FECHA INGRESO CLINICA   FECHA INGRESO SERVICIO FECHA POSIBLE ALTA  \
# 0                         NaN                      NaN                NaN
# 1                         NaN                      NaN                NaN
# 2     2018-02-21 05:21:03.340  2018-02-21 05:21:03.340                NaN
# 3     2018-05-19 15:07:11.027  2018-05-19 15:07:11.027                NaN
# 4     2018-07-26 12:44:55.287  2018-07-26 18:37:02.957                NaN
# ...                       ...                      ...                ...
# 6371  2021-02-25 00:39:45.387  2021-02-27 21:50:45.060                NaN
# 6372  2018-02-10 21:46:37.433  2018-02-12 14:36:01.400                NaN
# 6373  2018-03-14 01:06:14.860  2018-03-17 22:22:13.277                NaN
# 6374  2021-11-16 14:03:15.793  2021-11-18 17:51:59.490                NaN
# 6375  2021-10-28 02:27:30.293  2021-10-28 09:58:01.833                NaN
#
#             FECHA ALTA MEDICA            FECHA RECAUDO  \
# 0     2017-05-17 09:03:57.637                      NaN
# 1     2017-12-07 09:35:27.147                      NaN
# 2     2018-02-22 13:05:00.000                      NaN
# 3     2018-05-20 16:07:29.677                      NaN
# 4     2018-07-31 11:06:35.013                      NaN
# ...                       ...                      ...
# 6371  2021-03-04 11:42:00.000  2021-03-04 11:50:02.653
# 6372  2018-02-19 18:24:00.000                      NaN
# 6373  2018-03-27 14:36:00.000                      NaN
# 6374  2021-11-21 15:25:00.000  2021-11-21 15:58:38.213
# 6375  2021-10-31 21:14:00.000  2021-10-31 21:34:19.803
#
#               FECHA CAMILLERO         FECHA ENFERMERIA  \
# 0                         NaN                      NaN
# 1                         NaN                      NaN
# 2                         NaN                      NaN
# 3                         NaN                      NaN
# 4                         NaN                      NaN
# ...                       ...                      ...
# 6371  2021-03-04 12:34:52.843  2021-03-04 12:19:39.373
# 6372  2018-02-19 18:26:42.797                      NaN
# 6373  2018-03-27 14:51:07.360                      NaN
# 6374  2021-11-21 15:58:38.067  2021-11-21 16:09:12.223
# 6375  2021-10-31 21:34:19.670  2021-10-31 21:44:50.510
#
#      FECHA FACTURACION AUDIFARMA           FECHA FARMACIA  \
# 0                            NaN                      NaN
# 1                            NaN                      NaN
# 2        2018-02-22 14:30:20.003                      NaN
# 3                            NaN                      NaN
# 4                            NaN                      NaN
# ...                          ...                      ...
# 6371     2021-03-04 13:14:14.647  2021-03-04 12:01:39.270
# 6372     2018-02-19 11:59:12.223  2018-02-20 06:51:58.837
# 6373     2018-03-27 16:03:02.647  2018-03-27 17:27:44.310
# 6374     2021-11-21 15:51:16.597  2021-11-21 17:52:07.200
# 6375                         NaN  2021-10-31 21:31:32.650
#
#                  FECHA SALIDA               FECHA ASEO DEMORA ASIGNACION CAMA  \
# 0     2017-05-17 10:55:02.000                      NaN                  00:00
# 1     2017-12-07 11:06:49.000                      NaN                  00:00
# 2     2018-02-22 13:21:18.000                      NaN                   0:00
# 3     2018-05-20 16:14:41.000                      NaN                  00:00
# 4     2018-07-31 14:40:30.000                      NaN                  00:00
# ...                       ...                      ...                    ...
# 6371  2021-03-04 13:37:31.000  2021-03-04 15:50:52.257                   0:00
# 6372  2018-02-19 21:30:41.000  2019-09-10 11:16:24.807                  26:00
# 6373  2018-03-27 19:30:22.000  2019-09-10 11:16:24.807                  60:53
# 6374  2021-11-21 16:21:54.000  2021-11-21 17:47:33.883                   0:00
# 6375  2021-10-31 22:08:10.000  2021-10-31 22:52:41.873                   3:31
#
#      DEMORA APLICACION MEDICAMENTO  DEMORA SALIDA CLINICA (DIAS)  \
# 0                            00:00                           0.0
# 1                            00:00                           0.0
# 2                           -27:20                           0.0
# 3                            00:00                           0.0
# 4                            00:00                           0.0
# ...                            ...                           ...
# 6371                       -173:20                           0.0
# 6372                       -199:50                           0.0
# 6373                       -323:-2                           0.0
# 6374                       -114:00                           0.0
# 6375                        -76:00                           0.0
#
#      TRANSFUSION SANGRE ANTIBIOTICO ALTA MEDICA POSIBLE ALTA  \
# 0                    NO          NO         NaN          NaN
# 1                    NO          NO         NaN          NaN
# 2                    NO          SI          SI          NaN
# 3                    NO          NO         NaN          NaN
# 4                    NO          NO         NaN          NaN
# ...                 ...         ...         ...          ...
# 6371                 NO          NO          SI          NaN
# 6372                 NO          SI          SI          NaN
# 6373                 NO          SI          SI          NaN
# 6374                 NO          SI          SI          NaN
# 6375                 NO          NO          SI          NaN
#
#      DXPRINCIPAL EGRESO COD  \
# 0                      J441
# 1                      J441
# 2                      J441
# 3                      I110
# 4                      I110
# ...                     ...
# 6371                   I639
# 6372                   J188
# 6373                   S898
# 6374                   N390
# 6375                   I219
#
#                                      DXPRINCIPAL EGRESO DX RELACIONADO1 COD  \
# 0     ENFERMEDAD PULMONAR OBSTRUCTIVA CRONICA CON EX...                J984
# 1     ENFERMEDAD PULMONAR OBSTRUCTIVA CRONICA CON EX...                J960
# 2     ENFERMEDAD PULMONAR OBSTRUCTIVA CRONICA CON EX...                J980
# 3     ENFERMEDAD CARDIACA HIPERTENSIVA CON INSUFICIE...                I270
# 4     ENFERMEDAD CARDIACA HIPERTENSIVA CON INSUFICIE...                I082
# ...                                                 ...                 ...
# 6371                  INFARTO CEREBRAL  NO ESPECIFICADO                I671
# 6372  OTRAS NEUMONIAS  DE MICROORGANISMO NO ESPECIFI...                J440
# 6373     OTROS TRAUMATISMOS DE LA PIERNA  ESPECIFICADOS                W068
# 6374  INFECCION DE VIAS URINARIAS  SITIO NO ESPECIFI...                B962
# 6375  INFARTO AGUDO DEL MIOCARDIO  SIN OTRA ESPECIFI...                I130
#
#                                         DX RELACIONADO1 DX RELACIONADO2 COD  \
# 0                           OTROS TRASTORNOS DEL PULMON                J432
# 1                     INSUFICIENCIA RESPIRATORIA AGUDA                 I110
# 2     ENFERMEDADES DE LA TRAQUEA Y DE LOS BRONQUIOS ...                I10X
# 3                        HIPERTENSION PULMONAR PRIMARIA                J441
# 4       TRASTORNOS DE LAS VALVULAS AORTICA Y TRICUSPIDE                I270
# ...                                                 ...                 ...
# 6371                   ANEURISMA CEREBRAL  SIN RUPTURA                 I679
# 6372  ENFERMEDAD PULMONAR OBSTRUCTIVA CRONICA CON IN...                J80X
# 6373    CAIDA QUE IMPLICA CAMA  OTRO LUGAR ESPECIFICADO                T810
# 6374  ESCHERICHIA COLI [E. COLI] COMO CAUSA DE ENFER...                N12X
# 6375  ENFERMEDAD CARDIORRENAL HIPERTENSIVA CON INSUF...                I10X
#
#                                         DX RELACIONADO2 DX RELACIONADO3 COD  \
# 0                                ENFISEMA CENTROLOBULAR                J981
# 1     ENFERMEDAD CARDIACA HIPERTENSIVA CON INSUFICIE...                I270
# 2                     HIPERTENSION ESENCIAL (PRIMARIA)                 E872
# 3     ENFERMEDAD PULMONAR OBSTRUCTIVA CRONICA CON EX...                D728
# 4                        HIPERTENSION PULMONAR PRIMARIA                I517
# ...                                                 ...                 ...
# 6371       ENFERMEDAD CEREBROVASCULAR  NO ESPECIFICADA                 I739
# 6372                                                NaN                J980
# 6373  HEMORRAGIA Y HEMATOMA QUE COMPLICAN UN PROCEDI...                Y838
# 6374  NEFRITIS TUBULOINTERSTICIAL  NO ESPECIFICADA C...                N281
# 6375                  HIPERTENSION ESENCIAL (PRIMARIA)                 I500
#
#                                         DX RELACIONADO3  \
# 0                                     COLAPSO PULMONAR
# 1                        HIPERTENSION PULMONAR PRIMARIA
# 2                                              ACIDOSIS
# 3      OTROS TRASTORNOS ESPECIFICADOS DE LOS LEUCOCITOS
# 4                                        CARDIOMEGALIA
# ...                                                 ...
# 6371    ENFERMEDAD VASCULAR PERIFERICA  NO ESPECIFICADA
# 6372  ENFERMEDADES DE LA TRAQUEA Y DE LOS BRONQUIOS ...
# 6373                   OTROS PROCEDIMIENTOS QUIRURGICOS
# 6374                         QUISTE DE RINON  ADQUIRIDO
# 6375                 INSUFICIENCIA CARDIACA CONGESTIVA
#
#      TIPO DIAGNOSTICO PRINCIPAL PERTINENCIA DIAGNOSTICA  \
# 0                           NaN                     NaN
# 1                           NaN                     NaN
# 2                      Repetido                       p
# 3                           NaN                     NaN
# 4                           NaN                     NaN
# ...                         ...                     ...
# 6371                      Nuevo                     NaN
# 6372                      Nuevo                     NaN
# 6373                      Nuevo                     NaN
# 6374                      Nuevo                       p
# 6375                      Nuevo                       p
#
#      DX PRINCIPAL EGRESO CATEGORIA COD  \
# 0                                  J44
# 1                                  J44
# 2                                  J44
# 3                                  I11
# 4                                  I11
# ...                                ...
# 6371                               I63
# 6372                               J18
# 6373                               S89
# 6374                               N39
# 6375                               I21
#
#                           DX PRINCIPAL EGRESO CATEGORIA  \
# 0     OTRAS ENFERMEDADES PULMONARES OBSTRUCTIVAS CRO...
# 1     OTRAS ENFERMEDADES PULMONARES OBSTRUCTIVAS CRO...
# 2     OTRAS ENFERMEDADES PULMONARES OBSTRUCTIVAS CRO...
# 3                      ENFERMEDAD CARDIACA HIPERTENSIVA
# 4                      ENFERMEDAD CARDIACA HIPERTENSIVA
# ...                                                 ...
# 6371                                   INFARTO CEREBRAL
# 6372                NEUMONIA, ORGANISMO NO ESPECIFICADO
# 6373  OTROS TRAUMATISMOS Y LOS NO ESPECIFICADOS DE L...
# 6374              OTROS TRASTORNOS DEL SISTEMA URINARIO
# 6375                        INFARTO AGUDO DEL MIOCARDIO
#
#      DX PRINCIPAL EGRESO CAPITULO COD  \
# 0                             J00-J99
# 1                             J00-J99
# 2                             J00-J99
# 3                             I00-I99
# 4                             I00-I99
# ...                               ...
# 6371                          I00-I99
# 6372                          J00-J99
# 6373                          S00-T98
# 6374                          N00-N99
# 6375                          I00-I99
#
#                            DX PRINCIPAL EGRESO CAPITULO  \
# 0                ENFERMEDADES DEL SISTEMA RESPIRATORIO
# 1                ENFERMEDADES DEL SISTEMA RESPIRATORIO
# 2                ENFERMEDADES DEL SISTEMA RESPIRATORIO
# 3                ENFERMEDADES DEL SISTEMA CIRCULATORIO
# 4                ENFERMEDADES DEL SISTEMA CIRCULATORIO
# ...                                                 ...
# 6371             ENFERMEDADES DEL SISTEMA CIRCULATORIO
# 6372             ENFERMEDADES DEL SISTEMA RESPIRATORIO
# 6373  TRAUMATISMOS, ENVENENAMIENTO Y ALGUNAS OTRAS C...
# 6374           ENFERMEDADES DEL SISTEMA GENITOURINARIO
# 6375             ENFERMEDADES DEL SISTEMA CIRCULATORIO
#
#      CAUSA BASICA MUERTE COD CAUSA BASICA MUERTE CAUSA BASICA CATEGORIA COD  \
# 0                        NaN                 NaN                        NaN
# 1                        NaN                 NaN                        NaN
# 2                        NaN                 NaN                        NaN
# 3                        NaN                 NaN                        NaN
# 4                        NaN                 NaN                        NaN
# ...                      ...                 ...                        ...
# 6371                     NaN                 NaN                        NaN
# 6372                     NaN                 NaN                        NaN
# 6373                     NaN                 NaN                        NaN
# 6374                     NaN                 NaN                        NaN
# 6375                     NaN                 NaN                        NaN
#
#      CAUSA BASICA CATEGORIA CAUSA BASICA CAPITULO COD CAUSA BASICA CAPITULO  \
# 0                       NaN                       NaN                   NaN
# 1                       NaN                       NaN                   NaN
# 2                       NaN                       NaN                   NaN
# 3                       NaN                       NaN                   NaN
# 4                       NaN                       NaN                   NaN
# ...                     ...                       ...                   ...
# 6371                    NaN                       NaN                   NaN
# 6372                    NaN                       NaN                   NaN
# 6373                    NaN                       NaN                   NaN
# 6374                    NaN                       NaN                   NaN
# 6375                    NaN                       NaN                   NaN
#
#      PROFESIONAL ESPECIALIDAD                 PROFESIONAL ESPECIALIDAD GRD
# 0                         NaN                             Medicina Interna
# 1                         NaN                             Medicina Interna
# 2            Medicina Interna                                 Urgentologia
# 3            Medicina Interna                                 Urgentologia
# 4            Medicina Interna                             Medicina Interna
# ...                       ...                                          ...
# 6371         Medicina Interna                                   Neurologia
# 6372         Medicina Interna                                 Infectologia
# 6373                Ortopedia  Cirugia Plastica- Maxilofacial y de la Mano
# 6374         Medicina Interna                             Medicina Interna
# 6375         Medicina Interna                                   Nefrologia
#
# [6376 rows x 66 columns]

# %%
df_egresos = df_egresos[df_egresos["NRODOC"].isin(ids)]

# %%
# Calcula el porcentaje de valores nulos en cada variable
porcentaje_nulos = df_egresos.isna().apply(pd.Series.value_counts, normalize=True).T.fillna(0)

# Filtra las variables que tienen más del 10% de valores nulos
variables_con_nulos = porcentaje_nulos[porcentaje_nulos[True] > 0.1].index.values.tolist()
variables_con_nulos.remove('FECHA INGRESO CLINICA')
variables_con_nulos.remove('DX RELACIONADO3')


# Filtro de usuarios con causas de muerte registrada
mask_dead = ~df_egresos['CAUSA BASICA MUERTE COD'].isna() | ~df_egresos['CAUSA BASICA MUERTE'].isna() | ~df_egresos['CAUSA BASICA CATEGORIA COD'].isna() | ~df_egresos['CAUSA BASICA CATEGORIA'].isna() | ~df_egresos['CAUSA BASICA CAPITULO COD'].isna() | ~df_egresos['CAUSA BASICA CAPITULO'].isna()

# Eliminar usuarios con causas de muerte registrada
df_egresos.drop(df_egresos[mask_dead].index, inplace=True)

# Elimina las variables con más del 10% de valores nulos del DataFrame
df_egresos.drop(variables_con_nulos, axis=1, inplace=True)

# %%
na_cols = df_egresos.isna().sum()[df_egresos.isna().sum() > 0].index

# %%
causas = pd.read_excel("data/listas_de_causas.xlsx").ffill()
causas["COD_4"] = causas["COD_4"].str.replace("†", "")
na_cod = df_egresos.loc[~df_egresos["DXPRINCIPAL EGRESO COD"].isna() & df_egresos["DXPRINCIPAL EGRESO"].isna(), "DXPRINCIPAL EGRESO COD"].unique()
dic_cod = {}

for cod in range(len(na_cod)):

  try:
    dic_cod[na_cod[cod]] = causas.loc[causas["COD_3"] == na_cod[cod][:-1], "DESRIPCION CATEGORIAS DE TRES CARACTERES"].iloc[0] + causas.loc[causas["COD_4"] == na_cod[cod], "DESCRIPCION CODIGOS DE CUATRO CARACTERES"].iloc[0]
  except IndexError:
    try:
      dic_cod[na_cod[cod]] = causas.loc[causas["COD_3"] == na_cod[cod][:-1], "DESRIPCION CATEGORIAS DE TRES CARACTERES"].iloc[0]

    except IndexError:
      dic_cod[na_cod[cod]] = "No clasifcado"

full_cod = df_egresos.loc[~df_egresos["DXPRINCIPAL EGRESO"].isna(), "DXPRINCIPAL EGRESO COD"].unique()

for cod in range(len(full_cod)):

  dic_cod[full_cod[cod]] = df_egresos.groupby("DXPRINCIPAL EGRESO COD").get_group(full_cod[cod])["DXPRINCIPAL EGRESO"].unique()[0]

# ------------------------

set_1 = set(df_egresos.loc[~df_egresos["DX RELACIONADO1 COD"].isna() & df_egresos["DX RELACIONADO1"].isna(), "DX RELACIONADO1 COD"].unique())
set_2 = set(dic_cod.keys())

cod_r1 = df_egresos.loc[~df_egresos["DX RELACIONADO1 COD"].isna() & df_egresos["DX RELACIONADO1"].isna(), "DX RELACIONADO1 COD"].unique().tolist()

for i in set_1.intersection(set_2):
    cod_r1.remove(i)

for cod in range(len(cod_r1)):

  try:
    dic_cod[cod_r1[cod]] = causas.loc[causas["COD_3"] == cod_r1[cod][:-1], "DESRIPCION CATEGORIAS DE TRES CARACTERES"].iloc[0] + causas.loc[causas["COD_4"] == cod_r1[cod], "DESCRIPCION CODIGOS DE CUATRO CARACTERES"].iloc[0]
  except IndexError:
    try:
      dic_cod[cod_r1[cod]] = causas.loc[causas["COD_3"] == cod_r1[cod][:-1], "DESRIPCION CATEGORIAS DE TRES CARACTERES"].iloc[0]

    except IndexError:
      dic_cod[cod_r1[cod]] = "No clasifcado"

full_cod_r1 = df_egresos.loc[~df_egresos["DX RELACIONADO1"].isna(), "DX RELACIONADO1 COD"].unique()

for i in set_1.intersection(set(full_cod_r1)):
    full_cod_r1.remove(i)

for cod in range(len(full_cod_r1)):

  dic_cod[full_cod_r1[cod]] = df_egresos.groupby("DX RELACIONADO1 COD").get_group(full_cod_r1[cod])["DXPRINCIPAL EGRESO"].unique()[0]

# ------------------------

set_1 = set(df_egresos.loc[~df_egresos["DX RELACIONADO2 COD"].isna() & df_egresos["DX RELACIONADO2"].isna(), "DX RELACIONADO2 COD"].unique())
set_2 = set(dic_cod.keys())

cod_r2 = df_egresos.loc[~df_egresos["DX RELACIONADO2 COD"].isna() & df_egresos["DX RELACIONADO2"].isna(), "DX RELACIONADO2 COD"].unique().tolist()

for i in set_1.intersection(set_2):
    cod_r2.remove(i)

for cod in range(len(cod_r2)):

  try:
    dic_cod[cod_r2[cod]] = causas.loc[causas["COD_3"] == cod_r2[cod][:-1], "DESRIPCION CATEGORIAS DE TRES CARACTERES"].iloc[0] + causas.loc[causas["COD_4"] == cod_r2[cod], "DESCRIPCION CODIGOS DE CUATRO CARACTERES"].iloc[0]
  except IndexError:
    try:
      dic_cod[cod_r2[cod]] = causas.loc[causas["COD_3"] == cod_r2[cod][:-1], "DESRIPCION CATEGORIAS DE TRES CARACTERES"].iloc[0]

    except IndexError:
      dic_cod[cod_r2[cod]] = "No clasifcado"

full_cod_r2 = df_egresos.loc[~df_egresos["DX RELACIONADO2"].isna(), "DX RELACIONADO2 COD"].unique()

for i in set_1.intersection(set(full_cod_r2)):
    full_cod_r2.remove(i)

for cod in range(len(full_cod_r2)):

  dic_cod[full_cod_r2[cod]] = df_egresos.groupby("DX RELACIONADO2 COD").get_group(full_cod_r2[cod])["DX RELACIONADO2"].unique()[0]

# ------------------------
set_1 = set(df_egresos.loc[~df_egresos["DX RELACIONADO3 COD"].isna() & df_egresos["DX RELACIONADO3"].isna(), "DX RELACIONADO3 COD"].unique())
set_2 = set(dic_cod.keys())

cod_r3 = df_egresos.loc[~df_egresos["DX RELACIONADO3 COD"].isna() & df_egresos["DX RELACIONADO3"].isna(), "DX RELACIONADO3 COD"].unique().tolist()

for i in set_1.intersection(set_2):
    cod_r3.remove(i)

for cod in range(len(cod_r3)):

  try:
    dic_cod[cod_r3[cod]] = causas.loc[causas["COD_3"] == cod_r3[cod][:-1], "DESRIPCION CATEGORIAS DE TRES CARACTERES"].iloc[0] + causas.loc[causas["COD_4"] == cod_r3[cod], "DESCRIPCION CODIGOS DE CUATRO CARACTERES"].iloc[0]
  except IndexError:
    try:
      dic_cod[cod_r3[cod]] = causas.loc[causas["COD_3"] == cod_r3[cod][:-1], "DESRIPCION CATEGORIAS DE TRES CARACTERES"].iloc[0]

    except IndexError:
      dic_cod[cod_r3[cod]] = "No clasifcado"

full_cod_r3 = df_egresos.loc[~df_egresos["DX RELACIONADO3"].isna(), "DX RELACIONADO3 COD"].unique()

for i in set_1.intersection(set(full_cod_r3)):
    full_cod_r3.remove(i)

for cod in range(len(full_cod_r3)):

  dic_cod[full_cod_r3[cod]] = df_egresos.groupby("DX RELACIONADO3 COD").get_group(full_cod_r3[cod])["DX RELACIONADO3"].unique()[0]

# ------------------------

df_egresos["DEMORA ASIGNACION CAMA"] = df_egresos["DEMORA ASIGNACION CAMA"].str.extract("(\d*):").astype(int)*60 + df_egresos["DEMORA ASIGNACION CAMA"].str.extract(":(\d*)").astype(int)

df_egresos["DEMORA APLICACION MEDICAMENTO"] = df_egresos["DEMORA APLICACION MEDICAMENTO"].str.extract("(\d*):").astype(float)*60 + df_egresos["DEMORA APLICACION MEDICAMENTO"].str.extract(":(\d*)").replace("", 0).astype(int)

to_drop = ["DXPRINCIPAL EGRESO", "DX RELACIONADO1", "DX RELACIONADO2", "DX RELACIONADO3", "DX PRINCIPAL EGRESO CATEGORIA COD", "DX PRINCIPAL EGRESO CATEGORIA", 
           "DX PRINCIPAL EGRESO CAPITULO COD", "DX PRINCIPAL EGRESO CAPITULO", "TIPO IDENTIFICACION", "SERVICIO HABILITADO COD", "YEAR", "MES",
           "NRO INGRESO", "NRO ATENCION"]

for i in df_egresos.columns[df_egresos.columns.str.startswith("FECHA")]:
    df_egresos[i] = pd.to_datetime(df_egresos[i], format="mixed")
    
spanish_months = {"ENERO": 1, "FEBRERO": 2, "MARZO": 3, "ABRIL": 4,
                  "MAYO": 5, "JUNIO": 6, "JULIO": 7, "AGOSTO": 8,
                  "SEPTIEMBRE": 9, "OCTUBRE": 10, "NOVIEMBRE": 11, "DICIEMBRE": 12}

# Cambio de nombre a numero de mes
df_egresos["MES"] = df_egresos["MES"].replace(spanish_months)

ind = df_egresos[df_egresos["FECHA INGRESO CLINICA"].isna()].index


df_egresos["FECHA INGRESO CLINICA"].fillna(pd.to_datetime(df_egresos.loc[ind, "YEAR"].astype(str) + "-" + df_egresos.loc[ind, "MES"].astype(str), format="mixed"), inplace=True)

df_egresos.drop(df_egresos[df_egresos["SERVICIO ADMITE"] == 'AtenciÃ³n Domiciliaria'].index, inplace=True)

df_egresos["SERVICIO ADMITE"].ffill(inplace=True)

df_egresos.drop(to_drop, axis=1, inplace=True)

df_egresos.dropna(subset=["DX RELACIONADO1 COD", "DX RELACIONADO2 COD", "DX RELACIONADO3 COD"], how="any", inplace=True)

df_egresos["LOS"] = df_egresos["FECHA SALIDA"] - df_egresos["FECHA INGRESO CLINICA"]

# %% [markdown]
# # Cruce

# %%
# set_1 = set(df_usuarios_t["NRODOC"].unique().tolist())
# set_2 = set(df_cronicos["NRODOC"].unique().tolist())
# set_3 = set(df_egresos["NRODOC"].unique().tolist())
# set_T = set_1.intersection(set_2).intersection(set_3)
df_t = pd.merge(pd.merge(df_egresos , df_cronicos, on='NRODOC', how='inner'), df_usuarios_t, on="NRODOC", how="inner")

df_t.drop_duplicates(inplace=True, subset="LOS")

wid_1 = widgets.Dropdown(options=set_T)

def groupby(user):

  df = df_t.groupby("NRODOC").get_group(user)
  display(df)

output = interactive_output(groupby, {"user":wid_1})

display(wid_1, output)
# Out:
# Dropdown(options=(311296, 311301, 311302, 311303, 311304, 311305, 311312, 311342, 311347, 311348, 311349, 3113…
# Output()

# %%
def heatmap(df=..., annot=False):
    """
    Funcion para el mapa de correlacion de las variables numericas de un Data Frame
    devuele una figura de matplotlib
    
    Parametros
    ------------
        df: DataFrame con la informacion a dibujar
        annot: Mostrar valores en el grafico
    
    """
    
    
    assert isinstance(df, pd.DataFrame), "df debe ser un Dataframe"
    
    corr = df.drop("NRODOC", axis=1)._get_numeric_data().corr().round(2)
    
    
    sns.heatmap(corr.abs(), annot=annot);

# %%
heatmap(df_t)

# %%
def scatterplots(feats, df=..., nrows=4, ncols=3):
    
    
    assert isinstance(df, pd.DataFrame), "df debe ser un Dataframe"
    
    fig, axes = plt.subplots(nrows=nrows, ncols=ncols, figsize=(5, 8))
    i = 0
    j = 0
    
    for x, y in itertools.combinations(feats, r=2):
    
        df[[x, y]].plot.scatter(x=x, y=y, ax=axes[j], xlabel=f'{x}')
    
        if j!=0 and j%3 == 0:
            j = 0
            i += 1
        else:
            j += 1
    
    fig.suptitle("Mapas de dispersion para variables de alta correlacion")
    plt.tight_layout()

# %%
df_t.isna().sum()
# Out:
# NRODOC                                    0
# FECHA NACIMIENTO_x                        0
# SERVICIO ADMITE                           0
# UNIDAD ESTRATEGICA                        0
# FECHA INGRESO CLINICA                     0
# FECHA ALTA MEDICA                         0
# FECHA SALIDA                              0
# DEMORA ASIGNACION CAMA                    0
# DEMORA APLICACION MEDICAMENTO             0
# DEMORA SALIDA CLINICA (DIAS)              0
# TRANSFUSION SANGRE                        0
# ANTIBIOTICO                               0
# DXPRINCIPAL EGRESO COD                    0
# DX RELACIONADO1 COD                       0
# DX RELACIONADO2 COD                       0
# DX RELACIONADO3 COD                       0
# PROFESIONAL ESPECIALIDAD GRD              0
# LOS                                       0
# Fecha diligenciamiento                    0
# Atencion                                  0
# Peso                                      0
# Talla                                     0
# IMC                                       0
# Clasificacion IMC                         0
# Perimetro Muslo                           0
# Perimetro Cintura                         0
# Pliegue Triceps                           0
# Pliegue Abdomen                           0
# Pliegue Muslo                             0
# Sumatoria Pliegues                        0
# Presion Arterial Sistolica                0
# Presion Arterial Diastolica               0
# Frecuencia Cardiaca en reposo             0
# Auto-calificacion Nivel de Ejercicio      0
# Constantes                                0
# METS -Indice Metabolico                   0
# VO2 - Maxima Cantidad de Oxigeno          0
# Calificacion (Indice de Fragilidad)       0
# Tiempo en Segundos (Apoyo Monopodal)      0
# Calificacion (Apoyo Monopodal)            0
# Tiempo en Segundos (Recorrer 5 metros)    0
# Velocidad (m/s)                           0
# Calificacion Velocidad                    0
# SEXO                                      0
# FECHA NACIMIENTO_y                        0
# EDAD                                      0
# DATE                                      0
# dtype: int64

# %%
scatterplots(df_t, ["VO2 - Maxima Cantidad de Oxigeno", "IMC", "METS -Indice Metabolico"], ncols=3, nrows=1)
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[360], line 1
# ----> 1 scatterplots(df_t, ["VO2 - Maxima Cantidad de Oxigeno", "IMC", "METS -Indice Metabolico"], ncols=3, nrows=1)
#
# Cell In[359], line 14, in scatterplots(feats, df, nrows, ncols)
#       1 def scatterplots(feats, df=..., nrows=4, ncols=3):
#       3     """
#       4     Funcion para visualizacion de variables altamente correlacionadas
#       5
#    (...)
#      11         ncols = Columnas de la nueva grafica
#      12     """
# ---> 14     assert isinstance(df, pd.DataFrame), "df debe ser un Dataframe"
#      16     fig, axes = plt.subplots(nrows=nrows, ncols=ncols, figsize=(5, 8))
#      17     i = 0
#
# AssertionError: df debe ser un Dataframe

# %%
def barcharts(df=..., normalize=True, obj_col="Attrition", rotation=90, only=False, targ_col=...):
    """
    Funcion para la visualizacion de los histogramas de variables categoricas
    
    Parametros:
    --------------
        df: Data frame con la informacion
        normalize: Usar o no el promedio. Default True
        obj_col: Variable objetivo
        rotacion: rotacion de los ticks de la grafica
        only: True si solo se quiere visualiizar una variable. Default False
        targ_col: Columna a visualizar, solo sirve si only es True
    
    """
    
    
  
        assert isinstance(df, pd.DataFrame), "df debe ser un Dataframe"  
    
    
    
        data = df.select_dtypes(include=["object"])



  
        fig, axes = plt.subplots(nrows=4, ncols=4, figsize=(15, 15))
        x = 0
        y = 0
        
        for c in range(len(data.columns) - 1):
          
          if normalize:
            
        
            ax = axes[x,y]
            table = data.groupby(obj_col, as_index=False)[data.columns[c]].value_counts(normalize=normalize).round(2)
            order = sorted(table.iloc[:,1].unique())
            sns.barplot(data=table, x=table.columns[1], y="proportion", hue=obj_col, ax=ax, order=order)
        
            if len(order[0]) > 3:
                plt.setp(ax.xaxis.get_majorticklabels(), rotation=rotation)
        
        
            if y != 0 and y%3 == 0:
                y = 0
                x += 1
            else:
                y += 1
          
            
        
          else:
        
            ax = axes[x,y]
            table = data.groupby(obj_col, as_index=False)[data.columns[c]].value_counts(normalize=normalize).round(2)
            order = sorted(table.iloc[:,1].unique())
            sns.barplot(data=table, x=table.columns[1], y="count", hue=obj_col, ax=ax, order=order)
        
            if len(order[0]) > 3:
                plt.setp(ax.xaxis.get_majorticklabels(), rotation=rotation)
        
        
            if y != 0 and y%3 == 0:
                y = 0
                x += 1
            else:
                y += 1
        
  
    plt.tight_layout()
